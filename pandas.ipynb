# %%
import pandas as pd
df = pd.DataFrame({"Name":["amoshi","yoganandhu","sambu","heymal","kirfu","narayanan","dhamu","harihar"], "Department":["CSE","ECE","CSE","CSE","ECE","CSE","ECE","CSE"], "Marks":[75,85,90,80,70,88,92,78]})
attendance = pd.DataFrame({"Name":["amoshi","yoganandhu","sambu","heymal","kirfu","narayanan","dhamu","harihar"], "Attendance":[90,85,95,80,70,88,92,78]})
print("first 5 students:")
print(df.head(5))
# Out:
# first 5 students:
#          Name Department  Marks
# 0      amoshi        CSE     75
# 1  yoganandhu        ECE     85
# 2       sambu        CSE     90
# 3      heymal        CSE     80
# 4       kirfu        ECE     70

# %%
print("Average marks:", df["Marks"].mean())
# Out:
# Average marks: 82.25

# %%
print("marks more than 75:", df[df["Marks"] > 75])
# Out:
# marks more than 75:          Name Department  Marks
# 1  yoganandhu        ECE     85
# 2       sambu        CSE     90
# 3      heymal        CSE     80
# 5   narayanan        CSE     88
# 6       dhamu        ECE     92
# 7     harihar        CSE     78

# %%
print("attendance less than 80:", attendance[attendance["Attendance"] < 80])
# Out:
# attendance less than 80:       Name  Attendance
# 4    kirfu          70
# 7  harihar          78
